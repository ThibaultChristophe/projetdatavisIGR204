# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/marine/Documents/Telecom/P4/DataViz/projet/nat2016.txt", sep="\t")
df[df.preusuel =="BRICE"][df.annais =="1970"]
# Out:
# /Users/marine/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#         sexe preusuel annais  nombre
# 40447      1    BRICE   1970     222
# 319920     2    BRICE   1970       3

# %%
truc = df[["preusuel","sexe"]]
machin = {}
chouette =[]
#np.unique(truc)
truc = np.array(truc)
for t in truc : 
    if not t[0] in machin : 
        machin[t[0]] = t[1]
    else : 
        if machin [t[0]] != t[1] : 
            chouette.append(t[0])

set(chouette)
# Out:
# {'THIEN',
#  'SHEMSY',
#  'HILEL',
#  'LYLIAN',
#  'LUDOVIC',
#  'FRUMENCE',
#  'MARTIAL',
#  'EMANUELE',
#  'CÉCILE',
#  'MESSIE',
#  'NIRINA',
#  'APPOLINAIRE',
#  'ANTIDE',
#  'LOETARE',
#  'KELIG',
#  'DAMIEN',
#  'ELIDJAH',
#  'JAYA',
#  'MAI',
#  'ELY',
#  'IHSAN',
#  'MERY',
#  'MAELIG',
#  'MARIEL',
#  'RÉMI',
#  'SULPICE',
#  'AMEDEE',
#  'MACIRÉ',
#  'ROMUALD',
#  'LOAN',
#  'MERVEILLE',
#  'NAMA',
#  'NAHID',
#  'THOMAS',
#  'ADAM',
#  'AUXENCE',
#  'GERTRUDE',
#  'TANY',
#  'ELWEN',
#  'GERMAIN',
#  'MEDDY',
#  'GUENAEL',
#  'RAMA',
#  'ROMA',
#  'ANGELI',
#  'ISMAEL',
#  'IRMINE',
#  'LEOPOLD',
#  'TONY',
#  'JOSEPHA',
#  'MARC',
#  'WILLIE',
#  'MANEA',
#  'LOGAN',
#  'NICOLA',
#  'MALAURY',
#  'DIDIER',
#  'ELIE',
#  'AUDREY',
#  'BAHA',
#  'CHRISTIE',
#  'KACY',
#  'JILLIAN',
#  'ILKAY',
#  'ANDRIA',
#  'AELIG',
#  'MALY',
#  'SUN',
#  'SIMONE',
#  'EULALIE',
#  'NESTA',
#  'MITIA',
#  'VIVIAN',
#  'DABA',
#  'SIRIMA',
#  'SORIANE',
#  'YACINTHE',
#  'ELIYA',
# ...

# %%
df[df.preusuel=="A"]
# Out:
#    sexe preusuel annais  nombre
# 0     1        A   1980       3
# 1     1        A   1998       3
# 2     1        A   XXXX      22
