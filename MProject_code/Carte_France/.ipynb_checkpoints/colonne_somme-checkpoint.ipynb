# %%
import pandas as pd

# %%
df = pd.read_csv('output.csv')

# %%
df = df[df.annais != 'XXXX']

# %%
df = df[df.dpt !='XX']

# %%
df.head(10)
# Out:
#     sexe preusuel annais dpt  nombre
# 3      1    AADIL   1983  84       3
# 4      1    AADIL   1992  92       3
# 7      1    AARON   1962  75       3
# 8      1    AARON   1982  75       3
# 9      1    AARON   1984  75       3
# 10     1    AARON   1985  75       4
# 11     1    AARON   1989  75       3
# 12     1    AARON   1990  69       3
# 13     1    AARON   1990  75       4
# 14     1    AARON   1990  93       4

# %%
df.shape
# Out:
# (3475975, 5)

# %%
df = df.groupby(['annais','dpt'])[['nombre']].sum()

# %%
df.head(100)

# %%
df = df.merge(df.groupby([df.annais, df.dpt]).sum().rename(columns={'Result':'somme'}), 
... how='left', 
... left_on=[df.annais, df.dpt], 
... right_index=True) # When you do groupby, the columns you group by will be in the index

# %%
df.head()
# Out:
#    sexe_x preusuel annais dpt  nombre_x  sexe_y  nombre_y
# 3       1    AADIL   1983  84         3     596      5776
# 4       1    AADIL   1992  92         3    1543     21628
# 7       1    AARON   1962  75         3    1799     94183
# 8       1    AARON   1982  75         3    2212     35732
# 9       1    AARON   1984  75         3    2258     34891

# %%
df = df.drop(['sexe_y'], axis=1)

# %%
df.columns = ['sexe', 'preusuel', 'annais', 'dpt', 'nombre','somme']

# %%
df.head(15)
# Out:
#     sexe preusuel annais dpt  nombre  somme
# 3      1    AADIL   1983  84       3   5776
# 4      1    AADIL   1992  92       3  21628
# 7      1    AARON   1962  75       3  94183
# 8      1    AARON   1982  75       3  35732
# 9      1    AARON   1984  75       3  34891
# 10     1    AARON   1985  75       4  35427
# 11     1    AARON   1989  75       3  35937
# 12     1    AARON   1990  69       3  22714
# 13     1    AARON   1990  75       4  36331
# 14     1    AARON   1990  93       4  18797
# 15     1    AARON   1991  75       5  36366
# 16     1    AARON   1992  75       6  35098
# 17     1    AARON   1993  75       5  34196
# 18     1    AARON   1994  75       8  34507
# 19     1    AARON   1994  93       3  16963

# %%
df.to_csv('newCSV.csv', sep=',', index = False)
